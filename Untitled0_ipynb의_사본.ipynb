# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/EPA23_SHS/blob/main/Untitled0_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Today's new markdown

# %%
#@markdown Install and import libraries
# %%capture
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display
import pandas as pd

# %%
#@markdown Define ktts(), etts()
def etts(txt):
  tts = gTTS(txt, lang='en')
  tts.save("E-audio.mp3")
  return Audio("/content/E-audio.mp3")

def ktts(txt):
  tts = gTTS(txt, lang='ko')
  tts.save("K-audio.mp3")
  return Audio("/content/K-audio.mp3")

# %%
#@markdown Read csv file
url = ""
df = pd.read_csv(url)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe7bb8cfd85b> in <cell line: 3>()
#       1 #@markdown Read csv file
#       2 url = ""
# ----> 3 df = pd.read_csv(url)
#       4 df.head()
#
# NameError: name 'pd' is not defined

# %%
etts("Yesterday, A bag with an bran-new phone was stolen. ")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts("Someone stole the bag in the cafeteria at school. ")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts("The police caught three people they think might have done it. ")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts (" Right now, the three persons who are regarded as suspects are asked to write their alibi within 10 sentences. ")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts("The suspects say they can prove they didn't do the robbery and they insist they are innocent.")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Trial
