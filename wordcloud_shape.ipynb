# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/EPA23_SHS/blob/main/wordcloud_shape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# [text sample](https://raw.githubusercontent.com/MK316/workshops/main/20230512_GNU/images/textsample.txt)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Get user input
user_text = input("Enter your text: ")

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(user_text)

# Display the generated image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)

# Save the wordcloud image
plt.savefig("20230618_144556.png")

# Show the image
plt.show()
# Out:
# Enter your text: allibi

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Get user input
user_text = input("Enter your text:")

# List of keywords to emphasize
keywords = ["robbery", "suspect", "guilty", "alibi", "innocent", "bank"]

# Repeat the keywords multiple times to make them stand out
for keyword in keywords:
    user_text += " " + (keyword + " ") * 3


# Create a WordCloud object
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(user_text)

# Display the generated image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)

# Save the wordcloud image
plt.savefig("wordcloud.png")

# Show the image
plt.show()
# Out:
# Enter your text:innocent

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install wordcloud Pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# [GNU image](https://github.com/MK316/workshops/raw/main/20230512_GNU/images/GNU.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from PIL import Image, ImageOps

# Get user input
user_text = input("Enter your text: ")

# Load the "GNU" image as a mask
mask_image = Image.open("GNU.png").convert("L")
mask_image = ImageOps.invert(mask_image)  # Invert the mask image
mask = np.array(mask_image)

# Create a WordCloud object with the custom mask and black background
wordcloud = WordCloud(width=800, height=800, background_color='black', min_font_size=10, mask=mask,
                      contour_width=3, contour_color='turquoise').generate(user_text)

# Display the generated image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)

# Save the wordcloud image
plt.savefig("wordcloud_gnu.png")

# Show the image
plt.show()
# Out:
# Enter your text: AI, or artificial intelligence, is a rapidly growing field that is changing the way we live, work, and learn. As the world becomes more digitized, it is becoming increasingly important for individuals to develop digital literacy skills that will enable them to navigate and succeed in this new landscape. One key aspect of digital literacy is multimodality, which refers to the ability to use and understand a range of digital media and technologies.  Accessibility is also crucial in the digital era, as it is important that everyone has equal access to information and resources. Learning experience is another key factor in higher education, as educators strive to create engaging and effective learning environments that foster collaboration and lifelong learning. This involves leveraging technologies like AI and digital tools to enhance the learning experience and make it more personalized and effective.  Collaboration is also essential in the digital era, as it allows in
# ...

# %% [markdown]
# [multimodal image](https://github.com/MK316/workshops/raw/main/20230512_GNU/images/multimodal.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from PIL import Image, ImageOps

# Get user input
user_text = input("Enter your text: ")

# Replace "-" linked words with underscores "_"
user_text = user_text.replace("-", "_")

# Load the "GNU" image as a mask
mask_image = Image.open("multimodal.png").convert("L")
mask_image = ImageOps.invert(mask_image)  # Invert the mask image
mask = np.array(mask_image)

# Create a WordCloud object with the custom mask and black background
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10, mask=mask,
                      contour_width=3, contour_color='turquoise').generate(user_text)

# Display the generated image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)

# Save the wordcloud image
plt.savefig("wordcloud_gnu.png")

# Show the image
plt.show()
# Out:
# Enter your text: AI, or artificial intelligence, is a rapidly growing field that is changing the way we live, work, and learn. As the world becomes more digitized, it is becoming increasingly important for individuals to develop digital literacy skills that will enable them to navigate and succeed in this new landscape. One key aspect of digital literacy is multimodality, which refers to the ability to use and understand a range of digital media and technologies.  Accessibility is also crucial in the digital era, as it is important that everyone has equal access to information and resources. Learning experience is another key factor in higher education, as educators strive to create engaging and effective learning environments that foster collaboration and lifelong learning. This involves leveraging technologies like AI and digital tools to enhance the learning experience and make it more personalized and effective.  Collaboration is also essential in the digital era, as it allows in
# ...
